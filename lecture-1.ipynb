# %% [markdown]
# # Welcome to MUSA 620:<br>Data Wrangling and Data Visualization

# %% [markdown]
# ## My day job
#
# * My name is Nick Hand
# * I am the Director of Finance, Data, and Policy for City Controller Rebecca Rhynhart
# * Goals of our team:
#     - objective, data-driven analysis of financial policies impacting Philadelphia
#     - increasing transparency through data releases and interactive reports

# %% [markdown]
# * Recent projects:
#     - Analysis of the fairness and accuracy of property assessments
#     - Interactive reports for the City's cash levels
#     - Data releases for City expenditures
#     - Analysis of the 10-Year Tax Abatement program
# * Check out https://controller.phila.gov/policy-analysis

# %% [markdown]
# <center>
#     <img src="./images/controller-website.png"></img>
# </center>

# %% [markdown]
# ## Previously:<br>Astrophysics Ph.D. at Berkeley
# <br>
# <center>
# <img src="images/berkeley.jpeg" width=700></img>
# </center>

# %% [markdown]
# ## How did I get here?
#
# * Astrophysics to data science is becoming increasingly common
# * Landing a job through Twitter: https://www.parkingjawn.com
#     * Dashboard visualization of monthly parking tickets in Philadelphia
#     * Data from [OpenDataPhilly](https://www.opendataphilly.org/)
#
# **Goal: exploring and extracting insight from complex datasets**

# %% [markdown]
# ## Parking Jawn
# * https://www.parkingjawn.com
# * Cross-filtering
# * Different views
# * Show drop in parking tickets over Jan 24-26, 2016 due to snowstorm

# %% [markdown]
# # Class logistics

# %% [markdown]
# ## General info
#
# * 3-hour classes — mix of lecturing and interactive demonstrations
# * 10 minute break about halfway through
# * My email: nicholas.adam.hand@gmail.com
# * Office Hours:
#     - Tentatively, Mondays 6pm-8pm
#     - Remotely, through Skype or Google Hangouts

# %% [markdown]
# ## Course materials
#
# - Lectures and content hosted on GitHub: https://www.github.com/MUSA-620-Spring-2019

# %% [markdown]
# <center>
# <img src="images/musa-620-github.png" width=900></img>
# </center>

# %% [markdown]
# - Piazza:
#     - Still in the process of setting this up
#     - Will be used for Q & A and participation points

# %% [markdown]
# ## The goals of this course
#
# - Provide students with the knowledge and tools to turn data into meaningful insights and stories
# - Focus on the modern data science tools within the Python ecosystem
# - The pipeline approach to data science:
#     - gathering, storing, analyzing, and visualizing data to tell stories

# %% [markdown]
# ## What we'll cover

# %% [markdown]
# ### Module 1
#
# **Exploratory Data Science**: Students will be introduced to the main tools needed to get started analyzing and visualizing data using Python

# %% [markdown]
# ### Module 2
#
# **Geospatial Data Science**: Building on the previous set of tools, this module will teach students how to work with and extract insights from geospatial datasets using a range of modern Python toolkits

# %% [markdown]
# ### Module 3
#
# **Getting and Storing Data**: Students will learn how to collect new data through web scraping and APIs and store these datasets locally for efficient retrieval and analysis.

# %% [markdown]
# ### Module 4
#
# **Geospatial Data Science in the Wild**: Armed with the necessary data science tools, students will be introduced to a range of advanced analytic techniques using a number of innovative examples from modern researchers.

# %% [markdown]
# ### Module 5
# **From Exploration to Storytelling**: The final module will teach students to present their analysis results using web-based formats to transform their insights into interactive stories.

# %% [markdown]
# ## Assignments and grading
#
# - roughly one assignment per module, depending on their length
# - A final project that combines the data science tools learned in this class to analyze a data set and produce a web-based visualization

# %% [markdown]
# - Grading:
#     - 50% homework
#     - 40% final project
#     - 10% participation (both in class and on Piazza/GitHub)
# - Late policy: accepted up to 1 week late with a 10% deduction

# %% [markdown]
# ## Initial survey
#
# https://www.surveymonkey.com/r/55SX6RV

# %% [markdown]
# ### Okay, let's get started...

# %% [markdown]
# ## The Incredible Growth of Python
#
#
# [A StackOverflow analysis](https://stackoverflow.blog/2017/09/06/incredible-growth-python/)

# %% [markdown]
# <center>
#     <img src="images/stackoverflow-study-1.png" width=800><img>
# </center>

# %% [markdown]
# <center>
# <img src=images/stackoverflow-study-2.png width=750></img>
# </center>

# %% [markdown]
# ## The rise of the Jupyter notebook

# %% [markdown]
# ## The engine of collaborative data science
#
# - First started by a physics grad student around 2001
# - Known as the IPython notebook originally
# - Starting getting popular in ~2011
# - First funding received in 2015 $\rightarrow$ the Jupyter notebook was born

# %% [markdown]
# ### Google searches for Jupyter notebook
# <center>
#     <img src=attachment:Screen%20Shot%202019-01-22%20at%205.02.28%20PM.png width=1500></img>
# </center>

# %% [markdown]
# ## Key features
#
# - Aimed at "computational narratives" — telling stories with data
# - interactive, reproducible, shareable, user-friendly, visualization-focused

# %% [markdown]
# **very versatile: good for both exploratory data analysis and polished finished products**

# %% [markdown]
# ## Beyond the Jupyter notebook

# %% [markdown]
# ## Google's Colaboratory
#
# <center>
#     <img src=attachment:Screen%20Shot%202019-01-22%20at%206.14.54%20PM.png width=1000
#          ></img>
# </center>

# %% [markdown]
# - A fancier notebook experience built on top of Jupyter notebook
# - Running in the cloud on Google's servers
# - An internal Google product that was recently released publicly
# - Very popular for Python-based machine learning
# - Won't need to use much in this course

# %% [markdown]
# See https://colab.research.google.com/notebooks/welcome.ipynb

# %% [markdown]
# ## Binder: https://mybinder.org
#
# <center>
# <img src=attachment:Screen%20Shot%202019-01-22%20at%205.59.39%20PM.png></img>
# </center>

# %% [markdown]
# ### Allows you to launch a repository of Jupyter notebooks on GitHub in the cloud
#
# Note: as a free service, it can be a bit slow sometimes

# %% [markdown]
# ### Weekly lectures/assignments are available on Binder
# <center>
#     <img src=attachment:Screen%20Shot%202019-01-22%20at%206.08.34%20PM.png></img>
# </center>

# %% [markdown]
# To follow along, go to https://github.com/MUSA-620-Spring-2019/week-1

# %% [markdown]
# ## Now to the fun stuff...

# %% [markdown]
# These slides are a Jupyter notebook.
#
# A mix of *code* cells and **text** cells in Markdown.

# %%
# A simple code cell
# SHIFT-ENTER to execute

x = 10
print(x)
# Out:
# 10

# %% [markdown]
# ## Python Data Analysis: the *pandas* package
#
# Documentation is available at https://pandas.pydata.org
#
# <center>
# <img src=attachment:download.png width=400></img>
# </center>

# %% [markdown]
# The following line imports the *pandas* package:

# %%
import pandas as pd

# %% [markdown]
# ## Basic *pandas* concepts

# %% [markdown]
# The primary objects in *pandas* are the:
#
#   * **`DataFrame`**, which is very similar to an Excel spreadsheet, and has rows and named columns
#   * **`Series`**, which represents a single column of data. A `DataFrame` contains one or more `Series` and a name for each `Series`.
#
# The data frame is a commonly used abstraction for data manipulation. Similar implementations exist in [R](https://www.r-project.org/about.html).

# %% [markdown]
# To create a `Series` object:

# %%
# city names and population
city_names = pd.Series(['San Francisco', 'San Jose', 'Sacramento'])
population = pd.Series([852469, 1015785, 485199])

# %% [markdown]
# `DataFrame` objects can be created by passing a `dict` mapping `string` column names to their respective `Series`.

# %%
df = pd.DataFrame({ 'City Name': city_names, 'Population': population })
df
# Out:
#        City Name  Population
# 0  San Francisco      852469
# 1       San Jose     1015785
# 2     Sacramento      485199

# %% [markdown]
# ## Accessing data

# %%
df['Population']
# Out:
# 0     852469
# 1    1015785
# 2     485199
# Name: Population, dtype: int64

# %%
df[1:3]
# Out:
#     City Name  Population
# 1    San Jose     1015785
# 2  Sacramento      485199

# %% [markdown]
# *pandas* includes functionality for many different ways of selecting data. See [the documentation](https://pandas.pydata.org/pandas-docs/stable/indexing.html) for many more examples.

# %% [markdown]
# ## Manipulating data

# %%
df['Population'].sum()
# Out:
# 2353453

# %% [markdown]
# [NumPy](http://www.numpy.org/) is a popular toolkit for scientific computing.
#
# *pandas* `Series` can be used as arguments to most NumPy functions:

# %%
import numpy as np

# calculate the median population value
np.median(df['Population'])
# Out:
# 852469.0

# %% [markdown]
# For more complex single-column transformations, you can use `Series.apply`. It accepts a function that is applied to each value in the `Series`.
#
# For example, we can find which cities have a population greater than a million:

# %%
# define our function
def large_cities(population):
    return population > 1e6

# add the new computed column to our original data frame
df['Large Cities'] = df['Population'].apply(large_cities)

# we can also use lambda (unnamed, inline) functions
df['Small Cities'] = df['Population'].apply(lambda population: population < 1e6)

# print out 
df
# Out:
#        City Name  Population  Large Cities  Small Cities
# 0  San Francisco      852469         False          True
# 1       San Jose     1015785          True         False
# 2     Sacramento      485199         False          True

# %% [markdown]
# ### Data selection
#
# We can select the "large" cities by passing the boolean values to the `.loc()` function of a `DataFrame`:

# %%
large_cities = df.loc[df['Large Cities']]
large_cities
# Out:
#   City Name  Population  Large Cities  Small Cities
# 1  San Jose     1015785          True         False

# %%
# this is equivalent to doing 
df.loc[df['Population'] > 1e6]
# Out:
#   City Name  Population  Large Cities  Small Cities
# 1  San Jose     1015785          True         False

# %% [markdown]
# The documentation is your best friend! How to get help?

# %%
# use the question mark
pd.DataFrame.loc?

# %% [markdown]
# ## Now onto a more interesting example...

# %% [markdown]
# ## Analyzing trends in rentals rates over time

# %% [markdown]
# Let's load census data on rentals rates from the 2017 Amercian Community Survey.
#
# We've stored the data locally in the comma-separated value (CSV) format. Later in the course, you'll learn how to download them directly using Python.

# %% [markdown]
# Use the `read_csv()` function from *pandas*. The first argument to `read_csv()` is the file path to load.

# %%
df = pd.read_csv("./data/census/ACS_17_1YR_B25003.csv")

# %%
df.head()
# Out:
#              GEO.id  GEO.id2         GEO.display-label  HD01_VD01  HD02_VD01  \
# 0  1600000US0107000   107000  Birmingham city, Alabama      90186       3374
# 1  1600000US0121184   121184      Dothan city, Alabama      25192        875
# 2  1600000US0135896   135896      Hoover city, Alabama      34058       1330
# 3  1600000US0137000   137000  Huntsville city, Alabama      84750       2687
# 4  1600000US0150000   150000      Mobile city, Alabama      78145       2673
#
#    HD01_VD02  HD02_VD02  HD01_VD03  HD02_VD03
# 0      40295       2507      49891       3372
# 1      14935        763      10257        722
# 2      22913       1724      11145       1482
# 3      46677       2948      38073       2680
# 4      41297       2323      36848       2325

# %% [markdown]
# Select certain columns and rename them:

# %%
# columns we want
columns = ['GEO.display-label', 'HD01_VD01', 'HD01_VD03']
df2 = df[columns]

# rename columns
df2.columns = ['City', 'Total', 'Rentals']

df2.head()
# Out:
#                        City  Total  Rentals
# 0  Birmingham city, Alabama  90186    49891
# 1      Dothan city, Alabama  25192    10257
# 2      Hoover city, Alabama  34058    11145
# 3  Huntsville city, Alabama  84750    38073
# 4      Mobile city, Alabama  78145    36848

# %%
df2['Rental Rate'] = df2['Rentals'] / df2['Total'] * 100
# Out:
# /Users/nhand/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.head()
# Out:
#                        City  Total  Rentals  Rental Rate
# 0  Birmingham city, Alabama  90186    49891    55.320116
# 1      Dothan city, Alabama  25192    10257    40.715306
# 2      Hoover city, Alabama  34058    11145    32.723589
# 3  Huntsville city, Alabama  84750    38073    44.923894
# 4      Mobile city, Alabama  78145    36848    47.153369

# %% [markdown]
# We can select the largest cities by population using the `Series.isin()` function, which checks if each value in the `Series` is in the specified list.

# %%
top_cities = ['Philadelphia city, Pennsylvania', 
              'New York city, New York', 
              'Los Angeles city, California',
              'Houston city, Texas', 
              'Chicago city, Illinois', 
              'Phoenix city, Arizona']

selection = df2['City'].isin(top_cities) # which rows are valid
df2.loc[selection] # select the valid rows
# Out:
#                                 City    Total  Rentals  Rental Rate
# 18             Phoenix city, Arizona   559155   245335    43.876027
# 94      Los Angeles city, California  1384851   878061    63.404727
# 275           Chicago city, Illinois  1047695   577430    55.114322
# 426          New York city, New York  3159674  2127881    67.344954
# 474  Philadelphia city, Pennsylvania   606142   309279    51.024182
# 525              Houston city, Texas   837686   479409    57.230155

# %% [markdown]
# Now let's load data from 2005 to 2017:

# %%
data = []
for year in range(2005, 2018):
    
    # read data for this year
    year_str = str(year)[-2:]
    df = pd.read_csv("./data/census/ACS_%s_1YR_B25003.csv" % year_str)
     
    # columns we want
    columns = ['GEO.display-label', 'HD01_VD01', 'HD01_VD03']
    df = df[columns]

    # rename columns
    df.columns = ['City', 'Total', 'Rentals']
    
    # calculate the rental rate
    df['Rental Rate'] = df['Rentals'] / df['Total'] * 100
    
    # select the cities we want
    selection = df['City'].isin(top_cities)
    df = df.loc[selection]
    
    # add a column for the year
    df['Year'] = year
    
    # save 
    data.append(df)

# combine all of the data frames into one along the row axis
data = pd.concat(data, axis=0)

# %% [markdown]
# ## Basic plotting: `matplotlib`
#
# Much more to come next week. For now, we'll use some very simple plotting commands with Python's main plotting libary `matplotlib`.

# %% [markdown]
# Import the library we'll use from `matplotlib`.

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# We'll use the `plt.plot()` function which plots a simple `x` vs `y` line.

# %%
with plt.style.context('fivethirtyeight'):
    for city in data['City'].unique():
        this_city = data['City'] == city
        df = data.loc[this_city]
        plt.plot(df['Year'], df['Rental Rate'], label=city)

# format
plt.legend(loc=0, ncol=3)
ax = plt.gca()
ax.set_ylim(30, 72)
ax.set_ylabel("Rental Rate in Percent")
ax.figure.set_size_inches((10, 6))

# %% [markdown]
# ### From 2005 to 2017, Philadelphia had the largest percent increase
#
# **Exercise**: can you calculate what the increase was for Philadelphia?

# %% [markdown]
# ## Exercise solution

# %%
# select Philadelphia only
philly = data.loc[data['City']=='Philadelphia city, Pennsylvania']

# select 2005
x = philly.loc[philly['Year']==2005]
x = x['Rental Rate'].iloc[0]
print("2005 value = ", x)

# select 2017
y = philly.loc[philly['Year']==2017]
y = y['Rental Rate'].iloc[0]
print("2017 value = ", y)

# calculate percent change
percent_change = (y - x)/ y * 100

print("change in rental rate in Philadelphia from 2005 to 2017 = ", percent_change)
# Out:
# 2005 value =  43.292839293072745
# 2017 value =  51.02418245229665
# change in rental rate in Philadelphia from 2005 to 2017 =  15.152311683684621

# %% [markdown]
# For more details on the `iloc()` function, see the documentation on [indexing by position](https://pandas.pydata.org/pandas-docs/version/0.17.0/indexing.html#indexing-integer).

# %% [markdown]
# ## Now let's compare Zillow rental and home value data

# %% [markdown]
# Load citywide Zillow Rent Index (ZRI) and Zillow Home Value Index (ZHVI) data.
#
# Files were downloaded earlier from https://www.zillow.com/research/data/

# %%
home_values = pd.read_csv("./data/zillow/Metro_Zhvi_AllHomes.csv", engine='python')
rent_values = pd.read_csv('./data/zillow/Metro_Zri_SingleFamilyResidenceRental.csv', engine='python')

# %% [markdown]
# Peek at the first few rows of the ZRI data:

# %%
rent_values.head()
# Out:
#    RegionID                          RegionName  SizeRank  2010-11  2010-12  \
# 0    102001                       United States         0   1250.0   1248.0
# 1    394913                        New York, NY         1      NaN      NaN
# 2    753899  Los Angeles-Long Beach-Anaheim, CA         2   2283.0   2272.0
# 3    394463                         Chicago, IL         3   1581.0   1569.0
# 4    394514               Dallas-Fort Worth, TX         4   1297.0   1297.0
#
#    2011-01  2011-02  2011-03  2011-04  2011-05   ...     2018-02  2018-03  \
# 0   1245.0   1240.0   1236.0   1234.0   1236.0   ...        1411     1412
# 1      NaN      NaN      NaN      NaN      NaN   ...        2422     2417
# 2   2263.0   2259.0   2258.0   2263.0   2265.0   ...        2856     2866
# 3   1560.0   1551.0   1541.0   1534.0   1530.0   ...        1698     1696
# 4   1297.0   1298.0   1298.0   1300.0   1304.0   ...        1624     1622
#
#    2018-04  2018-05  2018-06  2018-07  2018-08  2018-09  2018-10  2018-11
# 0     1414     1416     1416     1415     1415     1414     1417     1426
# 1     2417     2418     2417     2416     2415     2415     2425     2438
# 2     2877     2886     2890     2892     2892     2893     2897     2911
# 3     1696     1696     1695     1694     1694     1693     1697     1713
# 4     1622     1621     1619     1618     1618     1616     1620     1630
#
# [5 rows x 100 columns]

# %% [markdown]
# And do the same for the ZHVI data:

# %%
home_values.head()
# Out:
#    RegionID                          RegionName  SizeRank   1996-04   1996-05  \
# 0    102001                       United States         0  100600.0  100600.0
# 1    394913                        New York, NY         1  165000.0  164800.0
# 2    753899  Los Angeles-Long Beach-Anaheim, CA         2  170600.0  170400.0
# 3    394463                         Chicago, IL         3  138300.0  138900.0
# 4    394514               Dallas-Fort Worth, TX         4  115300.0  115400.0
#
#     1996-06   1996-07   1996-08   1996-09   1996-10   ...     2018-02  \
# 0  100600.0  100700.0  100800.0  101000.0  101200.0   ...      211500
# 1  164600.0  164300.0  164100.0  163900.0  163800.0   ...      420800
# 2  170100.0  169800.0  169500.0  169300.0  169200.0   ...      635900
# 3  139300.0  139400.0  139300.0  138800.0  138000.0   ...      218000
# 4  115500.0  115700.0  115900.0  116100.0  116400.0   ...      222600
#
#    2018-03  2018-04  2018-05  2018-06  2018-07  2018-08  2018-09  2018-10  \
# 0   213200   214400   215600   216800   217900   219100   220200   221600
# 1   423400   425300   426600   427600   428600   429500   431100   433500
# 2   639000   640600   641900   643200   644700   646400   647500   648500
# 3   219300   219900   220500   220900   221100   221500   222100   222800
# 4   225500   227000   228400   230200   231700   232600   233800   235900
#
#    2018-11
# 0   222800
# 1   435700
# 2   650400
# 3   223600
# 4   237800
#
# [5 rows x 275 columns]

# %% [markdown]
# ## Selecting the cities we want

# %%
valid_cities = ['New York, NY', 'Chicago, IL', 
                'Los Angeles-Long Beach-Anaheim, CA', 
                'Philadelphia, PA', 'Houston, TX', 'Phoenix, AZ']

# %%
selection = home_values['RegionName'].isin(valid_cities)
home_values_trimmed = home_values.loc[selection]

# %%
selection = rent_values['RegionName'].isin(valid_cities)
rent_values_trimmed = rent_values.loc[selection]

# %% [markdown]
# ## Removing unwanted columns
#
# Unwanted columns can be *dropped* from the data frame using the `drop()` function.

# %%
unwanted = ['SizeRank', 'RegionID']
home_values_final = home_values_trimmed.drop(unwanted, axis=1)

# %%
unwanted = ['SizeRank', 'RegionID']
rent_values_final = rent_values_trimmed.drop(unwanted, axis=1)

# %% [markdown]
# ## Wide vs long format for datasets

# %% [markdown]
# Currently, our data is in **wide** format $\rightarrow$ each observation has its own column. This usually results in many columns but few rows.

# %%
home_values_final
# Out:
#                             RegionName   1996-04   1996-05   1996-06  \
# 1                         New York, NY  165000.0  164800.0  164600.0
# 2   Los Angeles-Long Beach-Anaheim, CA  170600.0  170400.0  170100.0
# 3                          Chicago, IL  138300.0  138900.0  139300.0
# 5                     Philadelphia, PA  109700.0  109700.0  109600.0
# 6                          Houston, TX       NaN       NaN       NaN
# 14                         Phoenix, AZ  104800.0  105400.0  106100.0
#
#      1996-07   1996-08   1996-09   1996-10   1996-11   1996-12   ...     \
# 1   164300.0  164100.0  163900.0  163800.0  163800.0  164000.0   ...
# 2   169800.0  169500.0  169300.0  169200.0  169200.0  169400.0   ...
# 3   139400.0  139300.0  138800.0  138000.0  137000.0  136100.0   ...
# 5   109500.0  109500.0  109400.0  109400.0  109400.0  109500.0   ...
# 6        NaN       NaN       NaN       NaN       NaN       NaN   ...
# 14  106700.0  107300.0  107900.0  108500.0  109000.0  109600.0   ...
#
#     2018-02  2018-03  2018-04  2018-05  2018-06  2018-07  2018-08  2018-09  \
# 1    420800   423400   425300   426600   427600   428600   429500   431100
# 2    635900   639000   640600   641900   643200   644700   646400   647500
# 3    218000   219300   219900   220500   220900   221100   221500   222100
# 5    225500   226100   226400   226800   227400   228100   228700   229400
# 6    194300   195800   196800   197900   199000   199700   200400   201200
# 14   248700   250300   251600   252900   254500   256100   257300   258600
#
#     2018-10  2018-11
# 1    433500   435700
# 2    648500   650400
# 3    222800   223600
# 5    230300   231100
# 6    202200   203200
# 14   260500   262000
#
# [6 rows x 273 columns]

# %% [markdown]
# Usually it's better to have data in [**tidy**](https://en.wikipedia.org/wiki/Tidy_data) (also known as **long**) format.
#
# Tidy datasets are arranged such that each variable is a column and each observation is a row.
#
# In our case, we want to have a column called `ZRI` and one called `ZHVI` and a row for each month that the indices were measured.

# %% [markdown]
# *pandas* provides the `melt()` function for converting from **wide** formats to **tidy** formats.

# %%
pd.melt?

# %% [markdown]
# Now, let's *melt* our datasets:

# %%
ZHVI = pd.melt(home_values_final, id_vars=['RegionName'], 
                value_name='ZHVI', var_name='Date')
ZRI = pd.melt(rent_values_final, id_vars=['RegionName'], 
              value_name='ZRI', var_name='Date')

# %% [markdown]
# and take a look:

# %%
ZHVI.head()
# Out:
#                            RegionName     Date      ZHVI
# 0                        New York, NY  1996-04  165000.0
# 1  Los Angeles-Long Beach-Anaheim, CA  1996-04  170600.0
# 2                         Chicago, IL  1996-04  138300.0
# 3                    Philadelphia, PA  1996-04  109700.0
# 4                         Houston, TX  1996-04       NaN

# %% [markdown]
# Note that missing data values are represented as `NaN` ("not a number")

# %% [markdown]
# ## Merging data frames

# %% [markdown]
# Another common operation is **merging**, also known as **joining**, two datasets.
#
# We can use the `merge()` function to merge observations that have the same `Date` and `RegionName` values.

# %%
data = pd.merge(ZRI, ZHVI, on=['Date', 'RegionName'], how='outer')

# %% [markdown]
# Merging is very powerful and the merge can be done in a number of ways. See the [infographic](joining_infographic.jpg) on joining in this repository.

# %% [markdown]
# ## Datetime objects
# Currently our `Date` column is stored as a `string`.
#
# *pandas* includes additional functionality for dates, but first we must convert the strings using the `to_datetime()` function.

# %%
# convert to data
data['Date'] = pd.to_datetime(data['Date'])

# %% [markdown]
# **Quick trick:** `Series` that hold `Datetime` objects have a `dt` attribute that let's you grab parts of the date easily.
#
# For example, we can easily add new columns for the month and year using:

# %%
data['Month'] = data['Date'].dt.month
data['Year'] = data['Date'].dt.year

# %%
data.head()
# Out:
#                            RegionName       Date     ZRI      ZHVI  Month  \
# 0                        New York, NY 2010-11-01     NaN  358800.0     11
# 1  Los Angeles-Long Beach-Anaheim, CA 2010-11-01  2283.0  410300.0     11
# 2                         Chicago, IL 2010-11-01  1581.0  182800.0     11
# 3                    Philadelphia, PA 2010-11-01  1557.0  204400.0     11
# 4                         Houston, TX 2010-11-01  1370.0  137500.0     11
#
#    Year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010

# %% [markdown]
# ## Annual trends: grouping by `Year`
#
# *pandas* is especially useful for grouping and aggregating data via the `groupby()` function.
#
# From the *pandas* documentation, `groupby` means:
# - **Splitting** the data into groups based on some criteria.
# - **Applying** a function to each group independently.
# - **Combining** the results into a data structure.
#
# The documentation is available [here](https://pandas.pydata.org/pandas-docs/stable/groupby.html).

# %% [markdown]
# We can calculate annual averages for each year by grouping by the `RegionName` and `Year` columns and taking the mean of our desired column. For example:

# %%
# calculate mean values for each Year and City (RegionName)
annual_ZHVI = data.groupby(['RegionName', 'Year'])['ZHVI'].mean() 
annual_ZRI = data.groupby(['RegionName', 'Year'])['ZRI'].mean()

# %%
print(type(annual_ZHVI))
# Out:
# <class 'pandas.core.series.Series'>

# %%
annual_ZHVI.head()
# Out:
# RegionName   Year
# Chicago, IL  1996    138344.444444
#              1997    130316.666667
#              1998    137841.666667
#              1999    147516.666667
#              2000    159900.000000
# Name: ZHVI, dtype: float64

# %% [markdown]
# Note that here that the result is indexed by the columns we grouped by (`RegionName` and `Year`).

# %% [markdown]
# We can **reset the index** so that the index values are listed as columns in the data frame again.

# %%
annual_ZHVI = annual_ZHVI.reset_index()
annual_ZRI = annual_ZRI.reset_index()

# %%
annual_ZHVI.head()
# Out:
#     RegionName  Year           ZHVI
# 0  Chicago, IL  1996  138344.444444
# 1  Chicago, IL  1997  130316.666667
# 2  Chicago, IL  1998  137841.666667
# 3  Chicago, IL  1999  147516.666667
# 4  Chicago, IL  2000  159900.000000

# %% [markdown]
# ## Plotting our results: ZHVI

# %%
with plt.style.context('fivethirtyeight'):
    for city in annual_ZHVI['RegionName'].unique():
        selection = annual_ZHVI['RegionName'] == city
        df = annual_ZHVI.loc[selection]
        
        plt.plot(df['Year'], df['ZHVI']/1e3, label=city)
    
    ax = plt.gca()
    ax.set_ylim(50, 800)
    ax.legend(loc=0, ncol=2)
    ax.figure.set_size_inches((10, 6))
    ax.set_ylabel('Zillow Home Value Index\n(in thousands of dollars)')

# %% [markdown]
# ### Home values in Philadelphia have recently recovered to pre-2008 levels

# %% [markdown]
# ## Plotting the results: Zillow Rent Index

# %%
with plt.style.context('fivethirtyeight'):
    for city in annual_ZRI['RegionName'].unique():
        selection = annual_ZRI['RegionName'] == city
        df = annual_ZRI.loc[selection]
        
        plt.plot(df['Year'], df['ZRI'], label=city)
    
    ax = plt.gca()
    ax.set_ylim(1000, 3300)
    ax.legend(loc=0, ncol=2)
    ax.set_ylabel('Zillow Rent Index (in dollars)')
    ax.figure.set_size_inches((10, 6))

# %% [markdown]
# ### Rent prices in Philadelphia have remained relatively flat, relative to other large cities.

# %% [markdown]
# ## First Homework Assignment

# %% [markdown]
# Available on GitHub:
#
# https://github.com/MUSA-620-Spring-2019/assignment-1

# %% [markdown]
# Two parts:
#
# 1. Download and install Anaconda locally
# 1. Analyze Zillow ZHVI data by ZIP code in Philadelphia, submitting your Jupyter notebook
#
# **Due date: by the start of next class**

# %% [markdown]
# **Note: analysis can be done using Binder if local Python installation runs into issues**

# %% [markdown]
# # That's it!
#
# - Office hours: next Monday, 6-8pm
# - Setting up Piazza soon for Q & A
# - Email questions/concerns to nicholas.adam.hand@gmail.com
